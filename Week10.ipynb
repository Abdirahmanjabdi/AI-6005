# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')


sid = SentimentIntensityAnalyzer()

text = "Python is such an amazing language!"
sentiment_score = sid.polarity_scores(text)

print(sentiment_score)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# {'neg': 0.0, 'neu': 0.55, 'pos': 0.45, 'compound': 0.6239}

# %%
from textblob import TextBlob

text = "Python is such an amazing language!"
analysis = TextBlob(text)

print(analysis.sentiment)
# Out:
# Sentiment(polarity=0.37500000000000006, subjectivity=0.7)

# %%
import sys
# !pip install vaderSentiment

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

text = "Python is such an amazing language!"
sentiment_score = analyzer.polarity_scores(text)

print(sentiment_score)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 11.7 MB/s eta 0:00:00
# ...
# {'neg': 0.0, 'neu': 0.55, 'pos': 0.45, 'compound': 0.6239}

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

X_train = ["I love this product", "This is terrible", "Not bad", "Amazing work"]
y_train = ["positive", "negative", "neutral", "positive"]

X_test = ["I hate this", "This is amazing"]


vectorizer = CountVectorizer()
X_train_counts = vectorizer.fit_transform(X_train)


classifier = MultinomialNB()
classifier.fit(X_train_counts, y_train)


X_test_counts = vectorizer.transform(X_test)
predictions = classifier.predict(X_test_counts)


accuracy = accuracy_score(["negative", "positive"], predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.5

# %%
import tweepy
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk


nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()


consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)


tweets = api.search_tweets(q="Python", count=10)


for tweet in tweets:
    sentiment_score = sid.polarity_scores(tweet.text)
    print(f"Text: {tweet.text}")
    print(f"Sentiment Score: {sentiment_score['compound']}")
    print("-----")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# /tmp/ipython-input-1023157524.py in <cell line: 0>()
#      20
#      21
# ---> 22 tweets = api.search_tweets(q="Python", count=10)
#      23
#      24
#
# /usr/local/lib/python3.12/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      30         @functools.wraps(method)
#      31         def wrapper(*args, **kwargs):
# ---> 32             return method(*args, **kwargs)
#      33         wrapper.pagination_mode = mode
#      34         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      43             kwargs['payload_list'] = payload_list
#      44             kwargs['payload_type'] = payload_type
# ...
